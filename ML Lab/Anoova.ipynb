# %% [markdown]
# # Lab 7 (Annova)

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
df = pd.read_csv('Annova1.csv')
df
# Out:
#     Employee  Edu_bac  Salary
# 0          1        1      11
# 1          2        1      10
# 2          3        1      11
# 3          4        1      23
# 4          5        1      21
# 5          6        1       9
# 6          7        1      13
# 7          8        1       7
# 8          9        1       5
# 9         10        1      16
# 10        11        2      15
# 11        12        2      32
# 12        13        2      43
# 13        14        2       2
# 14        15        2      31
# 15        16        2      43
# 16        17        2      66
# 17        18        2      73
# 18        19        2      11
# 19        20        2      21
# 20        21        3      34
# 21        22        3      25
# 22        23        3      13
# 23        24        3      14
# 24        25        3       9
# 25        26        3       7
# 26        37        3      12
# 27        28        3      22
# 28        29        3      31

# %%
import seaborn as sns
fig = sns.boxplot(x = "Edu_bac", y = "Salary", data = df)

# %%
ano1 = ols('Salary ~ Edu_bac', data = df).fit()
one1 = sm.stats.anova_lm(ano1, type=2)
one1
# Out:
#             df       sum_sq     mean_sq         F   PR(>F)
# Edu_bac    1.0   207.445831  207.445831  0.698179  0.41073
# Residual  27.0  8022.347273  297.123973       NaN      NaN

# %% [markdown]
# Annova 2

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
df = pd.read_csv('ANOVA2.csv')
df
# Out:
#     Employee  Edu_Back  Work_exp  Salary
# 0          1         1         1      10
# 1          2         1         2      14
# 2          3         1         1       8
# 3          4         1         1      17
# 4          5         1         1       9
# 5          6         1         2      22
# 6          7         1         2      16
# 7          8         2         2      26
# 8          9         2         2       3
# 9         10         2         1      10
# 10        11         2         1      17
# 11        12         2         1       2
# 12        13         2         1      18
# 13        14         2         1      21
# 14        15         2         2      21
# 15        16         2         2      12
# 16        17         2         2       7
# 17        18         3         1      19
# 18        19         3         1      11
# 19        20         3         2       5
# 20        21         3         2      17
# 21        22         3         1      24
# 22        23         3         1       2
# 23        24         3         1      21
# 24        25         3         1       9
# 25        26         3         2      25
# 26        27         3         2      15
# 27        28         3         2      20
# 28        29         3         2      10
# 29        30         3         2      17

# %%
ano1 = ols('Salary ~ Edu_Back', data = df).fit()
one1 = sm.stats.anova_lm(ano1, type=2)
one1
# Out:
#             df       sum_sq    mean_sq         F    PR(>F)
# Edu_Back   1.0     9.551064   9.551064  0.195445  0.661819
# Residual  28.0  1368.315603  48.868414       NaN       NaN

# %%
ano2 = ols('Salary ~ Edu_Back + Work_exp', data = df).fit()
one2 = sm.stats.anova_lm(ano2, type=2)
one2
# Out:
#             df       sum_sq    mean_sq         F    PR(>F)
# Edu_Back   1.0     9.551064   9.551064  0.192888  0.664018
# Work_exp   1.0    31.382508  31.382508  0.633785  0.432915
# Residual  27.0  1336.933095  49.516041       NaN       NaN
